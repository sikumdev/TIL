# %% [markdown]
# ### https://school.programmers.co.kr/learn/courses/30/lessons/81301
#
# - a.replace(old,new)

# %%
words = ["zero","one","two","three","four","five","six","seven","eight","nine"]
    
    buffer = ''
    
    for i,c in enumerate(s):
        if c.isalpha():
            buffer += c
        
        if buffer in words:
            s = s.replace(buffer,str(words.index(buffer))) # <- 인덱스값을 어떻게 찾지?
            buffer = ''
    
    return int(s)
