# %% [markdown]
#    create_agent() 실행
#    - model: 사용할 LLM 모델 (`"openai:gpt-4.1-mini"`)
#    - tools: 에이전트가 사용할 도구 리스트 (`[get_weather, calculator]`)
#    - system_prompt: 시스템 프롬프트 (`"You are a helpful assistant"`)
#    📦 입력: 모델 + 도구 + 프롬프트 설정 → 출력: agent 인스턴스
#
# 2. Agent 실행
#    agent.invoke() 실행
#    - messages: 사용자 메시지 리스트 (`[{"role": "user", "content": "..."}]`)
#    - `내부적으로 LLM이 메시지를 분석 → 필요한 tool 자동 선택 → tool 호출 → 결과 종합하여 응답 생성`
#    📦 입력: 사용자 메시지 → 출력: 에이전트 최종 응답
